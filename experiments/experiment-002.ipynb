# %%
# import gymnasium as gym  # noqa
# import gym_minipacman  # noqa
# import time  # noqa
from utils import plot_return  # noqa

# %%
env = gym.make("RegularMiniPacmanNoFrameskip-v0")
try:
    obs, info = env.reset()
    done = False
    while not done:
        # Pause for 1 second
        time.sleep(0.05)
        obs, reward, done, info = env.step(env.action_space.sample())
        env.render()
finally:
    env.close()
# Out:
# Viewer created

# %%
log_path_simple = "../storage/MiniPacman-test/log.csv"
log_path_recurrent = "../storage/MiniPacman-test-recurrent/log.csv"

plot_return(log_path_simple, "MiniPacman A2C")
plot_return(log_path_recurrent, "MiniPacman A2C Recurrent")
